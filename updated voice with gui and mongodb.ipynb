# %%
import tkinter as tk
from tkinter import *
from tkinter import font  as tkfont
from tkinter import ttk,PhotoImage
from tkinter.filedialog import askopenfilename
from tkinter.messagebox import askretrycancel
from tkinter.ttk import Combobox
from tkinter import ttk,PhotoImage
from tkinter import messagebox
from tkinter.messagebox import showinfo

import os
import pymongo
from pymongo import MongoClient
client = MongoClient('mongodb+srv://Pat:pratik@cluster0-uffad.mongodb.net/test?retryWrites=true&w=majority')
db = client.get_database('Users_db')
records = db.user_records

from PIL import ImageTk,Image
# %load_ext autoreload
# %autoreload 2

# %%
class SampleApp(tk.Tk):
    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        self.title_font = tkfont.Font(family='Helvetica', size=18, weight="bold", slant="italic")
        container = tk.Frame(self)
        container.pack(side="top", fill="both", expand=True)
        container.grid_rowconfigure(0, weight=1)
        container.grid_columnconfigure(0, weight=1)
        self.frames = {}
        for F in (StartPage,pg1,speak):
            page_name = F.__name__
            frame = F(parent=container, controller=self)
            self.frames[page_name] = frame
            frame.grid(row=0, column=0, sticky="nsew")
        self.show_frame("StartPage")
        
    def show_frame(self, page_name):
        '''Show a frame for the given page name'''
        frame = self.frames[page_name]
        frame.tkraise()


class StartPage(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        controller.geometry('1600x900')
        canvas = Canvas(self, width = 1600, height = 900, bg='#03e9fe', bd=0, highlightthickness=0)       
        canvas.place(x=0,y=0) 
        canvas.create_image(1600,900,anchor=CENTER)
        def donothing():
            print()
        menubar = tk.Menu(self)
        filemenu = tk.Menu(menubar, tearoff = 0)
        filemenu.add_command(label = "Start Page", command=lambda: controller.show_frame("StartPage"))
        filemenu.add_command(label = "Signup Page", command=lambda: controller.show_frame("pg1"))
        menubar.add_cascade(label = "Go to", menu = filemenu)
        controller.config(menu = menubar)
        
        canvas=Canvas(self, width = 1600, height = 900, bg='#03e9fe', bd=0, highlightthickness=0)       
        canvas.place(x=0,y=0)
        canvas.create_image(1600,900,anchor=CENTER)
        frm=self
        StartPage.canvas1 = Canvas(frm, width = 455, height = 500,bg='#03e9fe',highlightthickness=20)       
        StartPage.canvas1.place(x=400,y=50)
        
        dirp = os.getcwd()
        
        StartPage.gif = PhotoImage(file=(dirp+"\\image\\p.png"),master=frm)
        StartPage.canvas1.create_image(250,135, image=StartPage.gif)
        
        StartPage.uname = Label(frm,bg='#03e9fe',text="User-Name :", font=("Calibri",15)).place(x=465,y=280)
        StartPage.uname_entry = Entry(frm,font=("Calibri",15))
        StartPage.uname_entry.place(x=610,y=280)
        
        StartPage.Pass = Label(frm,bg='#03e9fe',text="Password... :", font=("Calibri",15)).place(x=465,y=355)
        StartPage.Pass_entry = Entry(frm,show="*",font=("Calibri",15))
        StartPage.Pass_entry.place(x=610,y=355)
        StartPage.LOGIN = Button(frm,bg='#fe0303', text='LOGIN',  width=20, command=lambda : StartPage.validate(self), font=("Calibri",10)).place(x=550,y=420)
        StartPage.SIGNUP= Button(frm, bg='#fe0303',text='SIGNUP',  width=20,command=lambda : StartPage.signup(self),   font=("Calibri",10)).place(x=550,y=475)
        
    def signup(self):
        self.controller.show_frame("pg1")
    def validate(self):
        xa=StartPage.uname_entry.get()
        ya=StartPage.Pass_entry.get()
        try:
            rec=records.find_one({'Child_Name':xa})
            if(rec['Child_Name']==xa and rec['Confirm_Password']==ya):
                messagebox.showinfo('Congratulations', 'You have successfully Loged in !')
                self.controller.show_frame("speak")

            else:
                print('Not')
                messagebox.showinfo('Sorry ','Please enter the correct username and password')

        except Exception as e:
            messagebox.showinfo('Sorry ','User does not exist')
            print("run again")
            print(e)

        
class speak(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        controller.geometry('1027x768')
        canvas = Canvas(self, width = 1600, height = 900, bg='#03e9fe', bd=0, highlightthickness=0)
        canvas.place(x=0,y=0)
        canvas.create_image(1600,900,anchor=CENTER)
        
        frm1 = self
        speak.canvas2=Canvas(frm1, width=500, height=450, bg='#03e9fe',highlightthickness=10)
        speak.canvas2.place(x=400,y=50)
        
        dirp = os.getcwd()
        
        speak.gif0 = PhotoImage(file=(dirp+"\\image\\p.png"),master=frm1)
        speak.canvas2.create_image(250,75, image=speak.gif0)
        
        speak.gif1 = PhotoImage(file=(dirp+"\\image\\pq.png"),master=frm1)
        speak.canvas2.create_image(250,230, image=speak.gif1)
        
        def recognize():
            import speech_recognition as sr
            r = sr.Recognizer()
            with sr.Microphone() as source:
                audio=r.listen(source)
            try:
                s = r.recognize_google(audio)
                print(s)
                #s=input('enter s : ')
                s1=''
                #print statements
                #print anything...
                if(s.startswith('print')):
                    s1=s[0:5]+"('"+s[5:]+"')"
                
                #print value of x, y, z
                if(s.startswith('print value of')):
                    l=[]
                    sta=s.find('of')
                    sta=sta+3
                    sub=s[sta:]
                    l=sub.split()
                    s1="print('values are ',"
                    for x in l:
                        s1=s1+x
                    s1=s1+")"
                
                #variable
                #declare x = 5
                #declare x, y = 2, abc
                if(s.startswith('declare')):
                    l=[]
                    s1=''
                    va1=[]
                    val=[]
                    l=s.split()
                    i=1
                    while(l[i] not in '='):
                        va1.append(l[i])
                        i=i+1
                    val=l[i+1:]
                    sta=s.find(' ')
                    stp=sta+1
                    while(s[stp]!=' '):
                        stp=stp+1
                    va=va1
                    for i in range(0,len(va)):
                        s1=s1+va[i]
                    s1=s1+' = '
                    for i in range(0,len(val)):
                        if(val[i][0].isnumeric()):
                            s1=s1+val[i]
                        else:
                            s1=s1+"'"+val[i]+"'"
                
                #make string X = A to Z
                if(s.startswith('make string')):
                    sta=s.find('string')
                    sta=sta+6
                    stp=sta+1
                    while(s[stp]!=' '):
                        stp=stp+1
                    va=s[sta:stp]
                    sta=s.find('=')
                    sta=sta+1
                    s1=va+" = "+"'"+s[sta+1:]+"'"
                
                #create dictionary x
                #create tuple x
                #create list x
                if(s.startswith('create')):
                    s1=''
                    l=[]
                    l=s.split()
                    if(l[1] in 'list'):
                        s1=l[2]+' = '+'[]'
                    elif(l[1] in 'tuple'):
                        s1=l[2]+' = '+'()'
                    elif(l[1] in 'dictionary'):
                        s1=l[2]+' = '+'{}'
                
                #looping statements
                #for i in range 0 to 9
                #for i in range 0 to 9 and step 2
                #for i in range 10 to 0 and step -3
                if(s.startswith('for')):
                    s1=''
                    l=[]
                    l=s.split()
                    s1="for "+l[1]+" in range("+l[4]+","+l[6]
                    if(len(l)>7):
                        s1=s1+","+l[9]
                    s1=s1+"):"
                
                #import statements
                #import xyz
                if(s.startswith('import')):
                    s1=s
                #from file import xyz
                if(s.startswith('from')):
                    s1=s
                #from file import star
                if(s.endswith('star')):
                    s1=s[0:-4]+"*"
                
                #define functions
                #define function xyz
                #define function xyz with parameter self, x, a, li
                if(s.startswith('define function ')):
                    sta=s.find('function')
                    sta=sta+len('function')
                    stp=sta+1
                    while(s[stp]!=' ' and stp!=(len(s)-1)):
                        stp=stp+1
                    va=s[sta:(stp+1)]
                    if(s.find('with parameter')>0):
                        l=[]
                        sta=s.find('with parameter')
                        sta=sta+len('with parameter')
                        sub=s[sta:]
                        l=sub.split()
                        for i in l:
                            if(i in 'coma'):
                                l.remove('coma')
                        
                        s1='def'+va+'('
                        for x in l:
                            s1=s1+x
                        #s1=s1[:-1]
                        s1=s1+'):'
                    else:
                        s1='def'+va+'():'
                
                #define class abc
                if(s.startswith('define class')):
                    s1=''
                    s1=s[7:]+':'
                
                #if statements
                #check if x is greater than y
                #check if x is less than y
                #check if x is equal to y
                #check if x is not equal to y
                #check if x is less than equal to y
                #check if x is greater than equal to y
                if(s.startswith('check if')):
                    l=[]
                    l=s.split()
                    va=l[2]
                    if((s.find('equla to'))>0):
                        try:
                            sta=s.find('equal to')
                            sta=sta+len('equal to')
                            n=w2n.word_to_num(s[sta:])
                            va2=str(n)
                        except:
                            va2=l[-1]
                    elif((s.find('than'))>0):
                        try:
                            sta=s.find('than')
                            sta=sta+len('than')
                            n=w2n.word_to_num(s[sta:])
                            va2=str(n)
                        except:
                            va2=l[-1]
                    s1='if('+va
                    if(l[3]=='is' and l[4]=='greater' and l[5]=='than' and l[6]!='equal'):
                        s1=s1+'>'
                    elif(l[3]=='is' and l[4]=='less' and l[5]=='than' and l[6]!='equal'):
                        s1=s1+'<'
                    elif(l[3]=='is' and l[4]=='equal' and l[5]=='to'):
                        s1=s1+'=='
                    elif(l[3]=='is' and l[4]=='not' and l[5]=='equal' and l[6]=='to'):
                        s1=s1+'!='
                    elif(l[3]=='is' and l[4]=='less' and l[5]=='than' and l[6]=='equal' and l[7]=='to'):
                        s1=s1+'<='
                    elif(l[3]=='is' and l[4]=='greater' and l[5]=='than' and l[6]=='equal' and l[7]=='to'):
                        s1=s1+'>='
                    s1=s1+va2+'):'
                
                print(s1)
                
            
            except Exception as e:
                print(e)
                print('translation is failed')
        
        speak.txt=tk.Text(self,height=8, width=60)
        speak.txt.place(x=600,y=500)
        speak.btn = Button(frm1, text='Speak Now',bg='#03e9fe', width=20, command=recognize, font=("Roboto",20)).place(x=505,y=420)
        #speak.p = Label(frm1,text="Recognizing Speech",bg='#03e9fe', font=("Calibri",15)).place(x=575,y=470)
        
        
class pg1(tk.Frame):
    def __init__(self, parent, controller):
        tk.Frame.__init__(self, parent)
        self.controller = controller
        controller.geometry('1600x900')
        canvas = Canvas(self, width = 1600, height = 900, bg='#03e9fe', bd=0, highlightthickness=0)
        canvas.place(x=0,y=0)
        canvas.create_image(1600,900,anchor=CENTER)
        
        frm2=self
        pg1.canvas3 = Canvas(frm2, width =455, height = 500,bg='#03e9fe',highlightthickness=20) 
        pg1.canvas3.place(x=400,y=50)
        dirp = os.getcwd()
        pg1.gif3 = PhotoImage(file=dirp+"\\image\\pq.png",master=frm2)
        pg1.canvas3.create_image(250,135, image=pg1.gif3)

        pg1.cname= Label(frm2,bg='#03e9fe',text="Enter Name :", font=("Calibri",15)).place(x=465,y=280)
        pg1.cname_entry = Entry(frm2,font=("Calibri",15))
        pg1.cname_entry.place(x=610,y=280)

        pg1.Dob= Label(frm2,bg='#03e9fe',text="Age :", font=("Calibri",15)).place(x=465,y=320)
        pg1.Dob_entry = Entry(frm2,font=("Calibri",15))
        pg1.Dob_entry.place(x=610,y=320)

        pg1.p= Label(frm2,bg='#03e9fe',text="Email id :", font=("Calibri",15)).place(x=465,y=360)
        pg1.p_entry = Entry(frm2,font=("Calibri",15))
        pg1.p_entry.place(x=610,y=360)

        pg1.Pas= Label(frm2,bg='#03e9fe',text="Password :", font=("Calibri",15)).place(x=465,y=400)
        pg1.pas_entry = Entry(frm2,show="*",font=("Calibri",15))
        pg1.pas_entry.place(x=610,y=400)

        pg1.cPass= Label(frm2,bg='#03e9fe',text="Confirm Pass :", font=("Calibri",15)).place(x=465,y=440)
        pg1.cpass_entry = Entry(frm2,show="*",font=("Calibri",15))
        pg1.cpass_entry.place(x=610,y=440)
        
        pg1.submit = Button(frm2, bg='#fe0303',text='Submit',command= lambda : pg1.data(self), width=20, font=("Calibri",10)).place(x=550,y=480)
        
    def data(self):
        x=pg1.cname_entry.get()
        y=pg1.Dob_entry.get()
        y1=int(y)
        z=pg1.p_entry.get()
        a=pg1.pas_entry.get()
        b=pg1.cpass_entry.get()
        if(a==b):
            n={'Child_Name':z,
               'Confirm_Password':a}
            records.insert_one(n)
            messagebox.showinfo('Success', 'User added successfully!')
            pg1.cname_entry.delete(0,'end')
            pg1.Dob_entry.delete(0,'end')
            pg1.p_entry.delete(0,'end')
            pg1.pas_entry.delete(0,'end')
            pg1.cpass_entry.delete(0,'end')
        else:
            messagebox.showinfo('error', 'password dident match..!!!')
    
        
if __name__ == "__main__":
    app = SampleApp()
    app.mainloop()
# Out:
# print value of x
# print('values are ',x)

# %%
import os

# %%
dirp = os.getcwd()
print(dirp+'')
# Out:
# C:\Users\Siddhidi\Desktop\heckathon
